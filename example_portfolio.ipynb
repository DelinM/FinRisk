# %%
import Portfolio
import datetime as dt

# %%
endDate = dt.datetime.now()
startDate = endDate - dt.timedelta(days=800)

# %%
init_cash = 100
# start_time = dt.datetime(2023, 1, 1)
# end_time = dt.datetime(2023, 4, 1)

my_protfolio = Portfolio.Portfolio(init_cash, startDate, endDate)

# %%
my_protfolio.add_stock('BBAI', 0.2)
my_protfolio.add_stock('MSFT', 0.2)
my_protfolio.add_stock('TSLA', 0.2)
my_protfolio.add_stock('U', 0.2)
my_protfolio.add_stock('WAL', 0.2)

# %%
my_protfolio.get_portfolio_history()
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %%
my_protfolio.apply_monte_carlo(60, 100)
my_protfolio.get_VaR(alpha=0.05)
my_protfolio.get_conditional_VaR(alpha=0.05)
my_protfolio.plot_monte_carlo()
# Out:
# 0.05
